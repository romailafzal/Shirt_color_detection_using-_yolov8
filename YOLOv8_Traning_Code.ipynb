# %% [markdown]
# # Train

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/yolov8
# Out:
# /content/drive/MyDrive/yolov8

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.166 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %% [markdown]
# to unzip  data set

# %%
# !unzip /content/drive/MyDrive/ML1_Training/v8/Shirtsv8.zip -d /content/drive/MyDrive/ML1_Training/v8/dataset2/
# Out:
# Archive:  /content/drive/MyDrive/ML1_Training/v8/Shirtsv8.zip
#  extracting: /content/drive/MyDrive/ML1_Training/v8/dataset2/README.dataset.txt
#  extracting: /content/drive/MyDrive/ML1_Training/v8/dataset2/README.roboflow.txt
#  extracting: /content/drive/MyDrive/ML1_Training/v8/dataset2/data.yaml
#    creating: /content/drive/MyDrive/ML1_Training/v8/dataset2/test/
#    creating: /content/drive/MyDrive/ML1_Training/v8/dataset2/test/images/
#  extracting: /content/drive/MyDrive/ML1_Training/v8/dataset2/test/images/000a99f66168fece_jpg.rf.aec2fc349b7ce33a7a5a85477fd44a0f.jpg
#  extracting: /content/drive/MyDrive/ML1_Training/v8/dataset2/test/images/0ce2db813f1453a0_jpg.rf.5c131192af2d9b67808bf65c8456e529.jpg
#  extracting: /content/drive/MyDrive/ML1_Training/v8/dataset2/test/images/0e51cd4469a4b4f0_jpg.rf.d8bb6fd6ca070f32d2ab45e79fd332e8.jpg
#  extracting: /content/drive/MyDrive/ML1_Training/v8/dataset2/test/images/0f8d13a46f3510b0_jpg.rf.5a6951987e9841876b29fc5300153dca.jpg
# ...

# %% [markdown]
# # actual training code

# %%
# !yolo detect train data=/content/drive/MyDrive/ML1_Training/v8/dataset2/data.yaml model=yolov8n.pt epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.166 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # prediction code

# %%
# !yolo predict model=/content/runs/detect/train2/weights/best.pt source=/content/WhatsApp.jpeg
# Out:
# Ultralytics YOLOv8.0.166 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3007013 parameters, 0 gradients
#
# image 1/1 /content/WhatsApp.jpeg: 640x480 1 shirt-blue, 128.1ms
# Speed: 4.1ms preprocess, 128.1ms inference, 93.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict7

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=/content/drive/MyDrive/yolov8/runs/detect/train2/weights/best.pt source=/content/drive/MyDrive/yolov8/pics/11.jpg
# !yolo predict model=/content/drive/MyDrive/yolov8/runs/detect/train2/weights/best.pt source=/content/drive/MyDrive/yolov8/pics/12.jpg
# !yolo predict model=/content/drive/MyDrive/yolov8/runs/detect/train2/weights/best.pt source=/content/drive/MyDrive/yolov8/pics/13.jpg
# !yolo predict model=/content/drive/MyDrive/yolov8/runs/detect/train2/weights/best.pt source=/content/drive/MyDrive/yolov8/pics/14.jpg
#
# Out:
# Ultralytics YOLOv8.0.165 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/yolov8/pics/11.jpg: 640x608 1 shirt-grey, 1 shirt-white, 142.1ms
# Speed: 5.3ms preprocess, 142.1ms inference, 157.3ms postprocess per image at shape (1, 3, 640, 608)
# Results saved to runs/detect/predict20
# Ultralytics YOLOv8.0.165 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/yolov8/pics/12.jpg: 640x640 1 shirt-blue, 1 shirt-white, 8.4ms
# Speed: 3.8ms preprocess, 8.4ms inference, 128.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict21
# Ultralytics YOLOv8.0.165 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients
#
# ...

# %% [markdown]
# #show predictions

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Path to the main detect folder
detect_folder_path = "/content/runs/detect"

# Get list of all subfolders with names like predict0, predict1, predict2, ...
predict_folders = [folder for folder in os.listdir(detect_folder_path) if folder.startswith("predict")]

# Function to plot images in a folder
def plot_images_in_folder(folder_path):
    image_files = [file for file in os.listdir(folder_path) if file.lower().endswith(('.png', '.jpg', '.jpeg'))]
    for image_file in image_files:
        image_path = os.path.join(folder_path, image_file)
        img = mpimg.imread(image_path)
        plt.imshow(img)
        plt.title(image_file)
        plt.axis('off')
        plt.show()

# Loop through each predict folder and plot images
for predict_folder in predict_folders:
    predict_folder_path = os.path.join(detect_folder_path, predict_folder)
    plot_images_in_folder(predict_folder_path)
